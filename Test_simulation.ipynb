# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

import numpy as np
from time import sleep
import json

from URBasic import Joint6D
from URBasic import TCP6D
from URBasic import TCP6DDescriptor

import src.calibration as Calibration
import src.space as Space

SIMULATION = True
# Create a new ISCoin object
# UR3e1 IP (closest to window): 10.30.5.158
# UR3e2 IP: 10.30.5.159
robot_ip = "iscoin_simulator"
robot_opened_gripper_size_mm = 40. # Max oppenning of gripper

# %%
file_path = "trapezoid_letters-trapezoid_letters-trace.json"
with open(file_path, "r", encoding="utf-8") as f:
    data = json.load(f)
print(data["generated_at"])
# Out:
# 2026-02-26T14:37:43.905785

# %%
p_world = np.array(data["calibration"])
if len(p_world) < 4:
    print("Missing point")

# %%
from my_simulation import ISCoinSim as ISCoin

iscoin = ISCoin(robot_ip, robot_opened_gripper_size_mm)
# Out:
# ISCoinSim connected to container 'iscoin_simulator'

# %%
robot_arm = iscoin.robot_control
# tcps = Calibration.collect_data(robot_arm, 20)
# tcp_offset = Calibration.get_tcp_offset(tcps)

# robot_arm.set_tcp(tcp_offset)
# robot_arm.freedrive_mode()
# tcp_ref = None
tcp_ref = TCP6D.createFromMetersRadians(-0.1310, -0.2700, 0.4099, 0, 3.1415, 0)
# while not tcp_ref:
#     i = input(f"Confirm reference position for TCP validation. y/n")
#     if i.lower()[0] == "y":
#         robot_arm.end_freedrive_mode()
#         joint_ref = robot_arm.get_actual_joint_positions()

# Calibration.validate_calibration(robot_arm, joint_ref)

# %%
# p_tcp = Space.collect_data(robot_arm, p_world)
p_tcp = np.array([
    [-0.030, -0.235, 0.030],
    [-0.030, -0.235, 0.070],
    [ 0.030, -0.235, 0.070],
    [ 0.060, -0.20,     0.010]
])
world_to_tcp = Space.affine_transform_rot_3D(p_world, p_tcp)

# %%
traces = data["traces"]
draw_motions = []
move_motions = []
above = [0,0,0.02,0,0,0]
for trace in traces:
    normal = trace["face"]
    normal[2] = - normal[2]
    t_world = trace["path"]
    motion = []
    buffer_motion = []
    
    # Drawing motion
    for i, p in enumerate(t_world):
        x,y,z,rx,ry,rz = world_to_tcp(p, normal)
        
        # Add entry point
        if i == 0:
            x_t,y_t,z_t,rx_t,ry_t,rz_t = Space.pose_trans([x,y,z,rx,ry,rz], above)
            t = TCP6D.createFromMetersRadians(x,y,z,rx,ry,rz)
            m = TCP6DDescriptor(t, a=5 ,v=1, t=0)
            buffer_motion.append(m)

        # Add drawing point
        t = TCP6D.createFromMetersRadians(x,y,z,rx,ry,rz)
        m = TCP6DDescriptor(t, a=5 ,v=1, t=0)
        buffer_motion.append(m)

        # Add exit point
        if i == len(t_world)-1:
            x_t,y_t,z_t,rx_t,ry_t,rz_t = Space.pose_trans([x,y,z,rx,ry,rz], above)
            t = TCP6D.createFromMetersRadians(x,y,z,rx,ry,rz)
            m = TCP6DDescriptor(t, a=5 ,v=1, t=0)
            buffer_motion.append(m)
        if len(buffer_motion) >= 20:
            motion.append(buffer_motion)
            buffer_motion = []
    if buffer_motion:
        motion.append(buffer_motion)
    if motion:
        draw_motions.append(motion)
        move_motions.append((motion[0][0], motion[-1][-1]))

# %%
move_outside = []
for m in range(len(move_motions)):
    if m == 0:
        move_outside.append([TCP6DDescriptor(tcp_ref, a=5 ,v=1, t=0), move_motions[m][0]])
    elif m == len(move_motions):
        move_outside.append([move_motions[m][1], TCP6DDescriptor(tcp_ref, a=5 ,v=1, t=0)])
    else:
        move_outside.append([move_motions[m-1][1], move_motions[m][0]])

# %%
len(draw_motions[0])
# Out:
# 13

# %%
for k in range(len(move_motions)):
    #py.move(move_outside[k])
    robot_arm.movel_waypoints(move_outside[k])
    for m in draw_motions[k]:
        robot_arm.movel_waypoints(m)
    break
# Out:
# movel_waypoints sent (2 points, total=4s)
# WARNING: Joint 1 error = 13.8° (target=-0.9689, actual=-1.2096)
# WARNING: Joint 2 error = 30.7° (target=-2.4286, actual=-1.8934)
# WARNING: Joint 3 error = 38.2° (target=-2.7127, actual=-2.0465)
# WARNING: Joint 4 error = 57.4° (target=0.4106, actual=-0.5917)
# WARNING: Joint 5 error = 5.7° (target=1.5315, actual=1.4318)
# WARNING: Joint 6 error = 6.2° (target=0.2720, actual=0.1632)
# Movement DONE — but target not fully reached (possible collision?)
# movel_waypoints sent (20 points, total=40s)
# WARNING: Joint 1 error = 10.6° (target=-0.9501, actual=-1.1355)
# WARNING: Joint 2 error = 25.9° (target=-2.4180, actual=-1.9662)
# WARNING: Joint 3 error = 26.2° (target=-2.7085, actual=-2.2517)
# WARNING: Joint 4 error = 26.6° (target=0.3950, actual=-0.0693)
# WARNING: Joint 5 error = 14.9° (target=1.5319, actual=1.2723)
# WARNING: Joint 6 error = 5.4° (target=0.2908, actual=0.1967)
# Movement DONE — but target not fully reached (possible collision?)
# movel_waypoints sent (20 points, total=40s)
# WARNING: Joint 1 error = 10.5° (target=-0.9141, actual=-1.0972)
# WARNING: Joint 2 error = 25.6° (target=-2.5054, actual=-2.0592)
# WARNING: Joint 3 error = 22.9° (target=-2.7446, actual=-2.3455)
# WARNING: Joint 4 error = 16.4° (target=0.5171, actual=0.2315)
# WARNING: Joint 5 error = 19.3° (target=1.5326, actual=1.1953)
# WARNING: Joint 6 error = 6.3° (target=0.3268, actual=0.2163)
# Movement DONE — but target not fully reached (possible collision?)
# movel_waypoints sent (20 points, total=40s)
# WARNING: Joint 1 error = 8.3° (target=-0.9118, actual=-1.0571)
# WARNING: Joint 2 error = 16.3° (target=-2.4410, actual=-2.1565)
# WARNING: Joint 3 error = 16.4° (target=-2.7191, actual=-2.4323)
# WARNING: Joint 4 error = 4.0° (target=0.4272, actual=0.4978)
# WARNING: Joint 5 error = 23.0° (target=1.5326, actual=1.1320)
# WARNING: Joint 6 error = 5.1° (target=0.3291, actual=0.2406)
# Movement DONE — but target not fully reached (possible collision?)
# movel_waypoints sent (20 points, total=40s)

# %%
traced = {
    "generated_at": "2026-02-26T09:32:30Z",
    "model": "trapezoid.obj",
    "texture": "trapezoid.png",
    "calibration": [
        [-30, 35.753, -19.358],
        [-30, 35.753, 19.358],
        [30, 35.753, 19.358],
        [60, 0, -40]
    ],
    "traces": [
        {
            "face": [0, 1, 0],
            "color": 0,
            "path": [
                [0, 0, 0],
                [0, 0.2, 0],
                [0.2, 0.2, 0]
            ]
        },
        {
            "face": [0, 0, 1],
            "color": 1,
            "path": [
                [0, 0, 0],
                [0, 0.2, 0],
                [0.2, 0.2, 0]
            ]
        }
    ]
}
